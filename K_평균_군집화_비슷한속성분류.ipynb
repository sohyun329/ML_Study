# %% [markdown]
# <a href="https://colab.research.google.com/github/sohyun329/ML_Study/blob/main/K_%ED%8F%89%EA%B7%A0_%EA%B5%B0%EC%A7%91%ED%99%94_%EB%B9%84%EC%8A%B7%ED%95%9C%EC%86%8D%EC%84%B1%EB%B6%84%EB%A5%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-평균 군집화
# - 비지도 학습의 대표적인 알고리즘
# - 목표 변수가 없는 상태에서 데이터를 비슷한 유형끼리 묶어내는 머신러닝 기법
# - KNN 알고리즘과 비슷하게 거리 기반으로 작동, 적절한 K값 사용자 지정
# - 거리 기반으로 작동하기 때문에 데이터 위치가 가까운 데이터끼리 한 그룹으로 묶음
# - 전체 그룹의 수 : 사용자가 지정한 K개
# - 장점 :
#   - 구현 비교적 간단
#   - 클러스터링 결과 쉽게 해석 가능
# - 단점 :
#   - 최적의 K값을 자동으로 찾지 못하고, 사용자가 직접 선택해야 한다
#   - 거리 기반 알고리즘이기 때문에, 변수의 스케일에 따라 다른 결과를 나타낼 수 있다
# - 유용한 곳
#   - 종속변수가 없는 데이터셋에서 데이터 특성을 비교적 간단하게 살펴보는 용도로 활용 가능
#   - 마케팅이나 제품 기획 등을 목적으로 한 고객 분류에 사용 가능
#   - 지도 학습에서 종속변수를 제외하고 사용하면, 탐색적 자료 분석 혹은 피처 엔지니어링 용도로 사용 가능

# %% [markdown]
# ## 1. Kmeans 연습

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_url = 'https://raw.githubusercontent.com/musthave-ML10/data_source/main/example_cluster.csv'
data = pd.read_csv(file_url)

# %%
data
# Out:
#          var_1     var_2
# 0     3.264413  6.929164
# 1     0.220814  2.251631
# 2    -8.786197 -8.333582
# 3    -0.008547  2.630791
# 4     4.912903  6.888520
# ..         ...       ...
# 995   4.678232  7.704404
# 996   5.250715  6.930948
# 997 -11.818752 -5.609853
# 998   0.613725  3.809334
# 999   3.516961  8.486305
#
# [1000 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['var_1', 'var_2'], dtype='object')

# %%
sns.scatterplot(x='var_1',y='var_2',data=data)
# Out:
# <Axes: xlabel='var_1', ylabel='var_2'>

# %%
from sklearn.cluster import KMeans

# %%
kmeans_model = KMeans(n_clusters=3, random_state=100)

# %%
kmeans_model.fit(data)
# Out:
# KMeans(n_clusters=3, random_state=100)

# %%
kmeans_model.predict(data)
# Out:
# array([2, 1, 0, 1, 2, 1, 2, 0, 2, 2, 2, 2, 1, 2, 0, 1, 0, 2, 2, 0, 1, 0,
#        0, 0, 1, 2, 1, 0, 1, 1, 1, 0, 1, 2, 2, 0, 0, 2, 2, 2, 1, 1, 2, 1,
#        0, 2, 2, 1, 0, 1, 2, 0, 2, 1, 2, 0, 0, 0, 1, 1, 1, 2, 1, 2, 0, 2,
#        1, 0, 2, 0, 1, 2, 1, 1, 1, 1, 2, 1, 1, 1, 2, 1, 0, 1, 2, 2, 1, 2,
#        0, 1, 2, 1, 0, 1, 0, 0, 0, 2, 1, 1, 1, 0, 0, 1, 0, 2, 0, 0, 0, 2,
#        0, 1, 2, 1, 1, 1, 0, 1, 0, 0, 2, 2, 1, 0, 1, 0, 1, 0, 2, 2, 0, 2,
#        1, 2, 0, 2, 1, 1, 1, 2, 1, 2, 0, 0, 1, 2, 0, 1, 1, 2, 2, 1, 1, 2,
#        2, 2, 1, 0, 2, 0, 2, 1, 2, 0, 0, 2, 1, 2, 0, 2, 1, 2, 0, 2, 2, 0,
#        1, 2, 0, 1, 1, 0, 1, 1, 2, 2, 2, 1, 2, 0, 1, 1, 1, 0, 2, 1, 1, 1,
#        2, 2, 2, 1, 1, 1, 2, 0, 1, 1, 1, 0, 0, 2, 1, 2, 1, 0, 0, 2, 1, 0,
#        1, 1, 0, 2, 0, 0, 2, 0, 2, 1, 0, 2, 2, 0, 0, 0, 2, 2, 2, 0, 1, 0,
#        2, 0, 0, 2, 1, 0, 2, 2, 0, 2, 1, 0, 2, 1, 0, 0, 1, 0, 2, 0, 2, 1,
#        1, 1, 0, 2, 1, 2, 2, 2, 2, 0, 2, 0, 1, 1, 2, 0, 1, 0, 2, 0, 1, 1,
# ...

# %%
data['label'] = kmeans_model.predict(data)

# %%
sns.scatterplot(x='var_1',y='var_2',data=data,hue='label',palette='rainbow')
# Out:
# <Axes: xlabel='var_1', ylabel='var_2'>

# %% [markdown]
# ### 엘보우 기법으로 최적의 K값 구하기
# - 실제 데이터는 변수가 너무 많아서 그래프로 확인하기도 어려울 뿐더러, 사람의 눈으로 보기에 정확하게 몇 개의 그룹인지 구분이 애매하다.
# - 즉, 사람의 눈에 의존해 적절한 K값을 찾는 데 한계가 있다.
# - 엘보우 기법 : 최적의 클러스터 개수를 확인하는 방법으로, 클러스터의 중점과 각 데이터 간의 거리를 기반으로 계산한다.
# - 이너셔 : 각 그룹에서의 중심과 각 그룹에 해당하는 데이터 간의 거리에 대한 합
#   - 클러스터의 중점과 데이터 간의 거리이기 때문에, 작을수록 그룹별로 더 오밀조밀 잘 모이게 분류됐다고 할 수 있다.
#   - 작을수록 좋다고 할 수 있으나 문제는 K값이 커지면 거리의 합인 이너셔는 필연적으로 작아지게 된다.

# %%
kmeans_model.inertia_
# Out:
# 3090.033237076663

# %%
temp_model = KMeans(n_clusters=500, random_state=100)
temp_model.fit(data)
temp_model.inertia_
# Out:
# 6.3412059092392274

# %%
distance = []
for k in range(2,10):
  k_model = KMeans(n_clusters=k)
  k_model.fit(data)
  distance.append(k_model.inertia_)

# %%
distance
# Out:
# [9908.551424778409,
#  3090.033237076663,
#  2757.3366520809577,
#  2410.5911879126106,
#  2055.64429444773,
#  1829.334090878178,
#  1688.4738872828614,
#  1382.205686278368]

# %%
sns.lineplot(x=range(2,10),y=distance)
# Out:
# <Axes: >

# %% [markdown]
# - 가장 급격하게 꺾이는 부분이 최적의 K

# %% [markdown]
# ## 2. 고객 데이터셋

# %%
file_url = 'https://raw.githubusercontent.com/musthave-ML10/data_source/main/customer.csv'
customer = pd.read_csv(file_url)

# %%
customer.head()
# Out:
#              cc_num       category     amt
# 0  2703186189652095           misc    4.97
# 1      630423337322        grocery  107.23
# 2    38859492057661  entertainment  220.11
# 3  3534093764340240  gas_transport   45.00
# 4   375534208663984           misc   41.96

# %%
customer['cc_num'].nunique()
# Out:
# 100

# %%
customer['category'].nunique()
# Out:
# 11

# %% [markdown]
# ## 3. 전처리 : 피처 엔지니어링

# %%
customer_dummy = pd.get_dummies(customer, columns=['category'])

# %%
customer_dummy.head()
# Out:
#              cc_num     amt  category_entertainment  category_food_dining  \
# 0  2703186189652095    4.97                   False                 False
# 1      630423337322  107.23                   False                 False
# 2    38859492057661  220.11                    True                 False
# 3  3534093764340240   45.00                   False                 False
# 4   375534208663984   41.96                   False                 False
#
#    category_gas_transport  category_grocery  category_health_fitness  \
# 0                   False             False                    False
# 1                   False              True                    False
# 2                   False             False                    False
# 3                    True             False                    False
# 4                   False             False                    False
#
#    category_home  category_kids_pets  category_misc  category_personal_care  \
# ...

# %%
cat_list = customer_dummy.columns[2:]

# %%
for i in cat_list:
  customer_dummy[i] = customer_dummy[i]*customer_dummy['amt']

# %%
customer_dummy
# Out:
#                   cc_num     amt  category_entertainment  \
# 0       2703186189652095    4.97                    0.00
# 1           630423337322  107.23                    0.00
# 2         38859492057661  220.11                  220.11
# 3       3534093764340240   45.00                    0.00
# 4        375534208663984   41.96                    0.00
# ...                  ...     ...                     ...
# 240449  4716561796955522    4.93                    0.00
# 240450    30074693890476  140.12                    0.00
# 240451    30404291151692   37.79                    0.00
# 240452  4922710831011201   17.50                   17.50
# 240453   213112402583773   25.49                    0.00
#
#         category_food_dining  category_gas_transport  category_grocery  \
# 0                        0.0                     0.0              0.00
# 1                        0.0                     0.0            107.23
# ...

# %%
customer_agg = customer_dummy.groupby('cc_num').sum()

# %%
customer_agg.head()
# Out:
#                     amt  category_entertainment  category_food_dining  \
# cc_num
# 60495593109    48149.62                 3169.74               4043.46
# 571365235126  259784.87                13864.51               9055.51
# 571465035400  270081.63                16162.98              15448.75
# 630412733309   41959.52                 3212.46               1543.16
# 630423337322  244612.73                12786.75               6905.07
#
#               category_gas_transport  category_grocery  \
# cc_num
# 60495593109                  5076.36           7576.58
# 571365235126                36525.79          48812.73
# 571465035400                 9081.62          41643.82
# 630412733309                 5786.98           8416.70
# 630423337322                36460.40          43854.26
#
#               category_health_fitness  category_home  category_kids_pets  \
# cc_num
# 60495593109                   1631.22        5458.58             4924.97
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(customer_agg),
                         columns = customer_agg.columns,
                         index=customer_agg.index)

# %%
scaled_df.head()
# Out:
#                    amt  category_entertainment  category_food_dining  \
# cc_num
# 60495593109  -1.402327               -1.135617             -0.971069
# 571365235126  1.079407                0.414075              0.168880
# 571465035400  1.200151                0.747127              1.622968
# 630412733309 -1.474915               -1.129427             -1.539741
# 630423337322  0.901491                0.257905             -0.320220
#
#               category_gas_transport  category_grocery  \
# cc_num
# 60495593109                -1.000180         -1.118217
# 571365235126                2.090013          0.767268
# 571465035400               -0.606627          0.439476
# 630412733309               -0.930355         -1.079803
# 630423337322                2.083588          0.540547
#
#               category_health_fitness  category_home  category_kids_pets  \
# cc_num
# 60495593109                 -1.561756      -1.145051           -1.276913
# ...

# %% [markdown]
# ## 4. 고객 데이터 모델링 및 실루엣 계수

# %%
distance = []
for k in range(2,10):
  k_model = KMeans(n_clusters=k)
  k_model.fit(scaled_df)
  labels = k_model.predict(scaled_df)
  distance.append(k_model.inertia_)

sns.lineplot(x=range(2,10),y=distance)
# Out:
# <Axes: >

# %% [markdown]
# - 어느 한 지점에서 크게 떨어지지 않고 비교적 완만한 그래프를 보임
# - K값을 결정하기 어려운 모양새
# - 실루엣 계수를 활용하여 해결
# - 실루엣 계수
#   - 엘보우 기법과 같이 최적의 클러스터 수를 찾는 방법으로, 엘보우 기법에서 적절한 클러스터 수를 찾지 못했을 때 대안
#   - 엘보우 기법보다 계산 시간이 오래 걸리는 단점이 있다
# - 엘보우 기법
#   - 각 클러스터의 중심과 그 클러스터에 속한 데이터 간의 거리로 계산
# - 실루엣 계수
#   - 클러스터 내부에서의 평균 거리와, 최근접한 다른 클러스터 데이터와의 평균 거리 반영

# %%
from sklearn.metrics import silhouette_score

silhouette = []
for k in range(2, 10):
    k_model = KMeans(n_clusters=k)
    k_model.fit(scaled_df)
    labels = k_model.predict(scaled_df)
    silhouette.append(silhouette_score(scaled_df, labels))

# %%
sns.lineplot(x=range(2,10),y=silhouette)
# Out:
# <Axes: >

# %% [markdown]
# ## 5. 최종 예측 모델 및 결과 해석

# %%
k_model = KMeans(n_clusters=4)
k_model.fit(scaled_df)
labels = k_model.predict(scaled_df)

# %%
scaled_df['label'] = labels

# %%
scaled_df_mean = scaled_df.groupby('label').mean()
scaled_df_count = scaled_df.groupby('label')['category_travel'].count()

# %%
scaled_df_count = scaled_df_count.rename('count')

# %%
scaled_df_all = scaled_df_mean.join(scaled_df_count)

# %%
scaled_df_all
# Out:
#             amt  category_entertainment  category_food_dining  \
# label
# 0      0.181113                0.043536              0.071197
# 1      1.908120                2.155375              1.796299
# 2     -0.983797               -0.826826             -0.820264
# 3      1.000533                0.776166              1.036432
#
#        category_gas_transport  category_grocery  category_health_fitness  \
# label
# 0                    0.868891          0.032581                 0.356233
# 1                   -0.490418          2.290553                 1.155923
# 2                   -0.807530         -0.746914                -1.037601
# 3                   -0.749213          0.310577                 1.175961
#
#        category_home  category_kids_pets  category_misc  \
# label
# 0           0.220808            0.524956       0.235603
# 1           0.943950            1.255997       2.005393
# 2          -0.943190           -1.017107      -0.788890
# ...
